# %% [markdown]
# # Introduction
#
# Some explanation...
#
# ## Example
#
# We first import pandas.

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 3.0.5

# %% [markdown]
# ## Loading data

# %%
df = pd.read_csv("../data/graded_Results.csv")
df.head()
# Out:
#                       file_id  \
# 0          ExamA_corrige1.pdf
# 1          ExamB_corrige1.pdf
# 2          ExamC_corrige1.pdf
# 3          ExamD_corrige1.pdf
# 4  20260821144631511_A_p1.png
#
#                                           input_path  \
# 0  inputs/exam_ECGE12320826/grayscale-80-gsm/Exam...
# 1  inputs/exam_ECGE12320826/grayscale-80-gsm/Exam...
# 2  inputs/exam_ECGE12320826/grayscale-80-gsm/Exam...
# 3  inputs/exam_ECGE12320826/grayscale-80-gsm/Exam...
# 4  /Users/heuchennecedric/OMRChecker-master/input...
#
#                                          output_path  score Identifiant q1_1  \
# 0  outputs/exam_ECGE12320826/grayscale-80-gsm/Che...      0         NaN    A
# 1  outputs/exam_ECGE12320826/grayscale-80-gsm/Che...      0         NaN   AC
# 2  outputs/exam_ECGE12320826/grayscale-80-gsm/Che...      0         NaN   BC
# 3  outputs/exam_ECGE12320826/grayscale-80-gsm/Che...      0         NaN    B
# ...
